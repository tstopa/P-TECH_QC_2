# %% [markdown]
# # Exercise 1
# Modify the notebook '2_QAOA_Statevector.ipynb' to solve and visualize MAXCUT problem for the following graph:
# ![image.png](attachment:861bc839-9a1f-420c-aa38-cbfad41fdf36.png)

# %% [markdown]
# # Exercise 2
# Modify the notebook '2_QAOA_Statevector.ipynb' to solve and visualize MAXCUT problem for the following weighted graph (you need to include weights in the definition of the operator/hamiltonian; you can google how to do this, but it is a trivial generalization of the regular MAXCUT problem):
# ![image.png](attachment:8a844fb8-c5be-4d28-ab52-1ab84a4a8b4c.png)

# %% [markdown]
# # Homework
# 1) Write brut-force solution to solve MAX_CUT problem for random graph with 20 nodes.
# Use random_geometric_graph() function from NetworkX to generate the graph and automated generation of operator/Hamiltonian based on graph definition as in [THIS](https://learning.quantum.ibm.com/tutorial/quantum-approximate-optimization-algorithm) tutorial - look for build_max_cut_paulis() function and adjust it work with networkx which we use
# 1) Try to find limit of your computer capabilities by increasing the number of nodes in the above brut-force approach. Quantum computers can find the soolution beyond this limit ;)
# 1) Run QAOA experiment on real quantum backend to solve Max Cut problem for random graph with 50 edges. Use '3_QAOA_real_backend.ipynb' notebook as a baseline and the Hamiltonian generation function you wrote for the previous two exercises. If you have failures before finding the minimum of the cost function, workaround it by noting down the parameters and running next attempt using their values from last iteration successfully executed.
